# %% [markdown]
# ## Convolution Neural Network
# You’ve seen how to add a convolutional 2d layer to the top of your neural network in the previous video. If you want to see more detail on how they worked, check out the playlist at https://bit.ly/2UGa7uH from Prof. Andrew Ng.

# %% [markdown]
# ![CNN.png](attachment:CNN.png)
# When the input image has size 28x28:
# 28x28 —> Conv2D(Kernel 3x3) —> new image (26x26 px)

# %% [markdown]
# ### Some Vertical line and Horizontal line filters by using CNN and their results
# ![Filters.png](attachment:Filters.png)

# %% [markdown]
# ### Max Pooling Operation
# ![Pooling.png](attachment:Pooling.png)

# %% [markdown]
# ## Implementing convolutional layers

# %%
import os
import tensorflow as tf 
print(tf.__version__)
# Out:
# 2022-12-01 08:52:15.104399: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-12-01 08:52:32.801442: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-11.7/lib64:/home/robotlab/anaconda3/envs/open3d/lib/python3.8/site-packages/PyQt5/Qt5/lib
# ...

# %% [markdown]
# ##  Improving Fashion MNIST dataset with CNN

# %%
import tensorflow as tf

# Load the Fashion MNIST dataset
fmnist = tf.keras.datasets.fashion_mnist
(training_images, training_labels), (test_images, test_labels) = fmnist.load_data()

# Normalize the pixel values
training_images = training_images / 255.0
test_images = test_images / 255.0

# %%
model = tf.keras.models.Sequential([
	# With 64 filters and kernel size 3x3.
	tf.keras.layers.Conv2D(64, (3,3), activation='relu', input_shape=(28,28,1)),
	tf.keras.layers.MaxPooling2D(2,2),
	tf.keras.layers.Conv2D(64,(3,3),activation='relu'),
	tf.keras.layers.MaxPooling2D(2,2),
	tf.keras.layers.Flatten(),
	tf.keras.layers.Dense(128, activation='relu'),
	tf.keras.layers.Dense(10, activation='softmax') 
])
#Show the detail the model
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 26, 26, 64)        640
#
#  max_pooling2d (MaxPooling2D  (None, 13, 13, 64)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 11, 11, 64)        36928
#
#  max_pooling2d_1 (MaxPooling  (None, 5, 5, 64)         0
#  2D)
#
#  flatten (Flatten)           (None, 1600)              0
#
#  dense (Dense)               (None, 128)               204928
#
#  dense_1 (Dense)             (None, 10)                1290
#
# ...
# Total params: 243,786
# Trainable params: 243,786
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Define the model
model = tf.keras.models.Sequential([
                                                         
  # Add convolutions and max pooling
  tf.keras.layers.Conv2D(32, (3,3), activation='relu', input_shape=(28, 28, 1)),
  tf.keras.layers.MaxPooling2D(2, 2),
  tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
  tf.keras.layers.MaxPooling2D(2,2),

  # Add the same layers as before
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dense(10, activation='softmax')
])

# Print the model summary
model.summary()

# Use same settings
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the model
print(f'\nMODEL TRAINING:')
model.fit(training_images, training_labels, epochs=5)

# Evaluate on the test set
print(f'\nMODEL EVALUATION:')
test_loss = model.evaluate(test_images, test_labels)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_2 (Conv2D)           (None, 26, 26, 32)        320
#
#  max_pooling2d_2 (MaxPooling  (None, 13, 13, 32)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 11, 11, 32)        9248
#
#  max_pooling2d_3 (MaxPooling  (None, 5, 5, 32)         0
#  2D)
#
#  flatten_1 (Flatten)         (None, 800)               0
#
#  dense_2 (Dense)             (None, 128)               102528
#
#  dense_3 (Dense)             (None, 10)                1290
#
# ...
# Total params: 113,386
# Trainable params: 113,386
# Non-trainable params: 0
# _________________________________________________________________
#
# MODEL TRAINING:
# Epoch 1/5
# 1875/1875 [==============================] - 34s 6ms/step - loss: 0.4793 - accuracy: 0.8270
# Epoch 2/5
# 1875/1875 [==============================] - 10s 6ms/step - loss: 0.3187 - accuracy: 0.8825
# ...

# %% [markdown]
# ### The result by using CNN (92-93%) more accuracy than Dense NN (86-87%). And the number of parameters more less

# %% [markdown]
# ## Visualizing the  Convolution and Pooling
# The print (test_labels[:100]) shows us the first 100 labels in the test set,
# and you can see that the ones at index 0, index 23 and index 28 are all the same value (9). They're all shoes

# %%
print(test_labels[:100])
# Out:
# [9 2 1 1 6 1 4 6 5 7 4 5 7 3 4 1 2 4 8 0 2 5 7 9 1 4 6 0 9 3 8 8 3 3 8 0 7
#  5 7 9 6 1 3 7 6 7 2 1 2 2 4 4 5 8 2 2 8 4 8 0 7 7 8 5 1 1 2 3 9 8 7 0 2 6
#  2 3 1 2 8 4 1 8 5 9 5 0 3 2 0 6 5 3 6 7 1 8 0 1 4 2]

# %%
import matplotlib.pyplot as plt
f, axarr = plt.subplots(3,4)
FIRST_IMAGE=0 # First row of image
SECOND_IMAGE=23 # Second row of image
THIRD_IMAGE=28  ## Third row of image


CONVOLUTION_NUMBER = 20 # The order number of Conv (in our case 0-63 Conv layer)
from tensorflow.keras import models
layer_outputs = [layer.output for layer in model.layers]
# 4 activation layers: Conv2D -> Pooling --> Conv2D --> Pooling 
activation_model = tf.keras.models.Model(inputs = model.input, outputs = layer_outputs)
for x in range(0,4):
    f1 = activation_model.predict(test_images[FIRST_IMAGE].reshape(1, 28, 28, 1))[x]
    axarr[0,x].imshow(f1[0, : , :, CONVOLUTION_NUMBER], cmap='inferno')
    axarr[0,x].grid(False)
    f2 = activation_model.predict(test_images[SECOND_IMAGE].reshape(1, 28, 28, 1))[x]
    axarr[1,x].imshow(f2[0, : , :, CONVOLUTION_NUMBER], cmap='inferno')
    axarr[1,x].grid(False)
    f3 = activation_model.predict(test_images[THIRD_IMAGE].reshape(1, 28, 28, 1))[x]
    axarr[2,x].imshow(f3[0, : , :, CONVOLUTION_NUMBER], cmap='inferno')
    axarr[2,x].grid(False)
# Out:
# ...
# 1/1 [==============================] - 0s 17ms/step

# %% [markdown]
# To visualizing the conv2D and Pooling, we can use this code bellow. It's can show each convolution filter by using CONVOLUTION_NUMBER parameter. We can change this from [0-63] and see the machine learn very specific location in the images depends on kind of filter.

# %% [markdown]
# ### Question 1: All observation running in only 5 epochs  Changing the number of filters from 64 to 32 or 16.

# %%
## Your code here

# %% [markdown]
# ### Question 2: Keep only 1 convolution filter and try with diffirent number of filters (16/32/64) + Pooling

# %%
## Your code here

# %% [markdown]
# ### Question 3: Adding more convolution layer and observed results

# %%
## Your code here
